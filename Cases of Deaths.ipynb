# %% [markdown]
# # CAUSE OF DEATHS

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\cause_of_deaths.csv")
df
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %%
# FIRST WE CREATE A SIMILAR TABLE TO ENSURE DATA INTEGRITY
df2 = df
df2
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %%
# NEXT WE DROP FOR DUPLICATES
df2.drop_duplicates()
df2
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %%
# WE MOVE STRAIGHT TO EXPLORATORY ANALYSIS AS THE DATA IS CLEANED

# EXPLORATORY ANALYSIS

# %%
# FIRST I WANT TO BE ABLE TO SEE ALL THE COLUMNS
pd.set_option('display.max.columns', 35)

# %%
df2
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %%
#1) WHAT DISEASE KILLS NIGERIANS THE MOST
# first we groupby the year and filter all the rows we want to show
nga_most_deaths = df2[df2['Country/Territory'] == 'Nigeria'].groupby('Year')[['Meningitis', 'Malaria', "Alzheimer's Disease and Other Dementias",
"Parkinson's Disease", 'Nutritional Deficiencies', 'Drowning', 'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS', 'Drug Use Disorders',
'Tuberculosis', 'Cardiovascular Diseases', 'Lower Respiratory Infections', 'Neonatal Disorders', 'Alcohol Use Disorders', 'Self-harm', 
'Exposure to Forces of Nature',	'Diarrheal Diseases', 'Environmental Heat and Cold Exposure', 'Neoplasms', 'Conflict and Terrorism',	
'Diabetes Mellitus', 'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',	'Road Injuries', 'Chronic Respiratory Diseases', 
'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',	'Fire, Heat, and Hot Substances', 'Acute Hepatitis']].sum()
nga_most_deaths
# Out:
#       Meningitis  Malaria  Alzheimer's Disease and Other Dementias  \
# Year
# 1990       40226   148931                                     4984
# 1991       41349   157502                                     5107
# 1992       42711   165722                                     5255
# 1993       44166   173695                                     5395
# 1994       45460   180588                                     5540
# 1995       46492   186263                                     5654
# 1996       59006   191437                                     5754
# 1997       48278   197467                                     5894
# 1998       50009   202843                                     6041
# 1999       50499   207571                                     6186
# 2000       51685   212123                                     6395
# 2001       52027   221139                                     6595
# 2002       53195   226408                                     6962
# ...

# %%
# Next we sum by all the rows and sort descending
nga_deaths = nga_most_deaths[['Meningitis', 'Malaria', "Alzheimer's Disease and Other Dementias",
"Parkinson's Disease", 'Nutritional Deficiencies', 'Drowning', 'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS', 'Drug Use Disorders',
'Tuberculosis', 'Cardiovascular Diseases', 'Lower Respiratory Infections', 'Neonatal Disorders', 'Alcohol Use Disorders', 'Self-harm', 
'Exposure to Forces of Nature',	'Diarrheal Diseases', 'Environmental Heat and Cold Exposure', 'Neoplasms', 'Conflict and Terrorism',	
'Diabetes Mellitus', 'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',	'Road Injuries', 'Chronic Respiratory Diseases', 
'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',	'Fire, Heat, and Hot Substances', 'Acute Hepatitis']].sum().sort_values(ascending= False)
nga_deaths
# Out:
# Diarrheal Diseases                            7449328
# Malaria                                       6422063
# Lower Respiratory Infections                  5917528
# Neonatal Disorders                            5262229
# Cardiovascular Diseases                       4176488
# HIV/AIDS                                      2216718
# Tuberculosis                                  1769390
# Digestive Diseases                            1716202
# Neoplasms                                     1618730
# Meningitis                                    1520376
# Cirrhosis and Other Chronic Liver Diseases     995203
# Chronic Respiratory Diseases                   641714
# Diabetes Mellitus                              541020
# Maternal Disorders                             525566
# Road Injuries                                  487695
# Chronic Kidney Disease                         464656
# Interpersonal Violence                         306846
# ...

# %%
# 2) What disease killed the most people in canada
canada = df2[df2['Country/Territory'] == 'Canada'].groupby('Year')[['Meningitis', 'Malaria', "Alzheimer's Disease and Other Dementias",
"Parkinson's Disease", 'Nutritional Deficiencies', 'Drowning', 'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS', 'Drug Use Disorders',
'Tuberculosis', 'Cardiovascular Diseases', 'Lower Respiratory Infections', 'Neonatal Disorders', 'Alcohol Use Disorders', 'Self-harm', 
'Exposure to Forces of Nature',	'Diarrheal Diseases', 'Environmental Heat and Cold Exposure', 'Neoplasms', 'Conflict and Terrorism',	
'Diabetes Mellitus', 'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',	'Road Injuries', 'Chronic Respiratory Diseases', 
'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',	'Fire, Heat, and Hot Substances', 'Acute Hepatitis']].sum()
canada
# Out:
#       Meningitis  Malaria  Alzheimer's Disease and Other Dementias  \
# Year
# 1990         128        0                                     6456
# 1991         126        0                                     6549
# 1992         121        0                                     6649
# 1993         132        0                                     6785
# 1994         119        0                                     6948
# 1995         108        0                                     7167
# 1996         103        0                                     7423
# 1997         111        0                                     7685
# 1998          99        0                                     7970
# 1999         113        0                                     8266
# 2000         113        0                                     8587
# 2001         116        0                                     8938
# 2002         109        0                                     9294
# ...

# %%
canada_deaths = canada[['Meningitis', 'Malaria', "Alzheimer's Disease and Other Dementias",
"Parkinson's Disease", 'Nutritional Deficiencies', 'Drowning', 'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS', 'Drug Use Disorders',
'Tuberculosis', 'Cardiovascular Diseases', 'Lower Respiratory Infections', 'Neonatal Disorders', 'Alcohol Use Disorders', 'Self-harm', 
'Exposure to Forces of Nature',	'Diarrheal Diseases', 'Environmental Heat and Cold Exposure', 'Neoplasms', 'Conflict and Terrorism',	
'Diabetes Mellitus', 'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',	'Road Injuries', 'Chronic Respiratory Diseases', 
'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',	'Fire, Heat, and Hot Substances', 'Acute Hepatitis']].sum().sort_values(ascending= False)
canada_deaths
# Out:
# Cardiovascular Diseases                       2213352
# Neoplasms                                     2112700
# Chronic Respiratory Diseases                   402093
# Alzheimer's Disease and Other Dementias        317320
# Digestive Diseases                             288628
# Lower Respiratory Infections                   214127
# Diabetes Mellitus                              195320
# Chronic Kidney Disease                         145149
# Self-harm                                      133442
# Cirrhosis and Other Chronic Liver Diseases     123127
# Road Injuries                                   92479
# Parkinson's Disease                             82441
# Drug Use Disorders                              37251
# Neonatal Disorders                              31372
# Alcohol Use Disorders                           30411
# Diarrheal Diseases                              29015
# HIV/AIDS                                        17171
# ...

# %%
#3 What country did most people Drown
drown = df2[df2['Drowning'] >= 0].groupby('Country/Territory')['Drowning'].sum().sort_values(ascending=False)
drown
# Out:
# Country/Territory
# China           2873619
# India           2110438
# Bangladesh       711803
# Russia           423044
# Brazil           250078
#                  ...
# Cook Islands         30
# San Marino            0
# Tokelau               0
# Andorra               0
# Niue                  0
# Name: Drowning, Length: 204, dtype: int64

# %%
# 4 What country did most people die of HIV/Aids
Aids = df2[df2["HIV/AIDS"] >= 0].groupby('Country/Territory')['HIV/AIDS'].sum().sort_values(ascending=False)
Aids
# Out:
# Country/Territory
# South Africa    4874296
# Kenya           2583539
# Tanzania        2465047
# India           2454374
# Nigeria         2216718
#                  ...
# Maldives             12
# Tuvalu                7
# Nauru                 6
# Tokelau               0
# Niue                  0
# Name: HIV/AIDS, Length: 204, dtype: int64

# %%
# 5 What Country did Alcohol kill the most
Alcohol = df2[df2["Alcohol Use Disorders"] >= 0].groupby('Country/Territory')['Alcohol Use Disorders'].sum().sort_values(ascending=False)
Alcohol
# Out:
# Country/Territory
# Russia           1194672
# India             527112
# China             485796
# United States     309757
# Ukraine           303062
#                   ...
# Niue                   0
# San Marino             0
# Cook Islands           0
# Nauru                  0
# Tokelau                0
# Name: Alcohol Use Disorders, Length: 204, dtype: int64

# %%
#6 Country with most "self-harm" deaths
Self_harm = df2[df2["Self-harm"] >= 0].groupby('Country/Territory')['Self-harm'].sum().sort_values(ascending=False)
Self_harm
# Out:
# Country/Territory
# India                    5543395
# China                    5078550
# Russia                   1793855
# United States            1168886
# Japan                     861712
#                           ...
# Antigua and Barbuda           65
# Saint Kitts and Nevis         60
# Tuvalu                        60
# Tokelau                        0
# Niue                           0
# Name: Self-harm, Length: 204, dtype: int64

# %%
#7 In recent Years how many Nigerians have been killed by forces of nature
nga_nature = df2[df2["Country/Territory"] == 'Nigeria'].groupby('Year')["Exposure to Forces of Nature"].value_counts()
nga_nature
# Out:
# Year  Exposure to Forces of Nature
# 1990  0                               1
# 1991  0                               1
# 1992  0                               1
# 1993  0                               1
# 1994  30                              1
# 1995  0                               1
# 1996  0                               1
# 1997  0                               1
# 1998  15                              1
# 1999  189                             1
# 2000  36                              1
# 2001  200                             1
# 2002  0                               1
# 2003  16                              1
# 2004  94                              1
# 2005  60                              1
# 2006  40                              1
# 2007  91                              1
# 2008  0                               1
# 2009  31                              1
# 2010  40                              1
# 2011  185                             1
# ...

# %%
#8 Is tuberculorsis a disease swedish people should be wary of?
swede_tb = df2[df2["Country/Territory"] == "Sweden"].groupby('Year')['Tuberculosis'].sum()
swede_tb
# Out:
# Year
# 1990    197
# 1991    197
# 1992    193
# 1993    188
# 1994    177
# 1995    177
# 1996    170
# 1997    170
# 1998    167
# 1999    166
# 2000    155
# 2001    155
# 2002    155
# 2003    142
# 2004    134
# 2005    132
# 2006    130
# 2007    125
# 2008    118
# 2009    109
# 2010     99
# 2011     96
# 2012     92
# 2013     87
# 2014     81
# 2015     78
# 2016     77
# 2017     76
# 2018     78
# 2019     79
# Name: Tuberculosis, dtype: int64

# %%
#9) Does Fire Kill a lot of People in Japan?
japanese_fire = df2[df2["Country/Territory"] == "Japan"].groupby('Year')['Fire, Heat, and Hot Substances'].sum()
japanese_fire
# Out:
# Year
# 1990    1580
# 1991    1600
# 1992    1647
# 1993    1674
# 1994    1706
# 1995    1757
# 1996    1753
# 1997    1758
# 1998    1798
# 1999    1866
# 2000    1823
# 2001    2025
# 2002    1822
# 2003    1840
# 2004    1831
# 2005    1874
# 2006    1847
# 2007    1824
# 2008    1807
# 2009    1773
# 2010    1768
# 2011    1775
# 2012    1734
# 2013    1889
# 2014    1638
# 2015    1589
# 2016    1573
# 2017    1571
# 2018    1606
# 2019    1617
# Name: Fire, Heat, and Hot Substances, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %%
#10 Country That died with the most digestive disease in 2000
digest_dth = df2[df2["Year"] == 2000].groupby('Country/Territory')["Digestive Diseases"].sum().sort_values(ascending=False)
digest_dth
# Out:
# Country/Territory
# India            385059
# China            302427
# Indonesia        100417
# United States     92314
# Russia            70085
#                   ...
# Cook Islands          4
# Tuvalu                4
# Nauru                 3
# Tokelau               1
# Niue                  1
# Name: Digestive Diseases, Length: 204, dtype: int64

# %%
#10 How many Nigerians die of Protein Malnutrition in Year 2010
digest_dth = df2[(df2["Year"] == 2000) & (df2["Country/Territory"] == "Nigeria")].groupby('Country/Territory')["Protein-Energy Malnutrition"].sum().sort_values(ascending=False)
digest_dth
# Out:
# Country/Territory
# Nigeria    11334
# Name: Protein-Energy Malnutrition, dtype: int64

# %%
# 11 In What nation is Diarrhea considered almost insignificant
diarrhea = df2[df2['Diarrheal Diseases'] >= 0].groupby('Country/Territory')['Diarrheal Diseases'].sum().sort_values(ascending= True)
diarrhea
# Out:
# Country/Territory
# Tokelau              0
# Niue                 0
# San Marino           0
# Monaco               0
# Bermuda             11
#                 ...
# Ethiopia       2514592
# Indonesia      2590656
# Pakistan       3187522
# Nigeria        7449328
# India         26243547
# Name: Diarrheal Diseases, Length: 204, dtype: int64

# %%
#12 Is environmental heat and cold a problem for norwegians?
norway_climate = df2[df2['Country/Territory'] == 'Norway'].groupby('Year')['Environmental Heat and Cold Exposure'].sum()
norway_climate
# Out:
# Year
# 1990    34
# 1991    33
# 1992    32
# 1993    31
# 1994    29
# 1995    29
# 1996    27
# 1997    29
# 1998    30
# 1999    30
# 2000    32
# 2001    33
# 2002    34
# 2003    34
# 2004    36
# 2005    32
# 2006    32
# 2007    32
# 2008    32
# 2009    34
# 2010    35
# 2011    36
# 2012    35
# 2013    36
# 2014    34
# 2015    33
# 2016    33
# 2017    31
# 2018    31
# 2019    32
# Name: Environmental Heat and Cold Exposure, dtype: int64

# %%
#13 What year did people die of poison the most
poison_year = df2[df2['Poisonings'] > 0].groupby('Year')['Poisonings'].sum().sort_values(ascending= False)
poison_year
# Out:
# Year
# 2005    92064
# 2004    91455
# 1994    90897
# 2003    90634
# 1995    90353
# 1993    90036
# 2002    89920
# 2006    89859
# 2001    89294
# 1996    88861
# 2000    88799
# 2008    88687
# 2007    88475
# 1992    88435
# 1990    87951
# 2009    87902
# 1991    87813
# 2010    87632
# 1997    87371
# 1999    87333
# 1998    86679
# 2011    86099
# 2012    84595
# 2013    83618
# 2014    81976
# 2015    80974
# 2016    79951
# 2017    78484
# 2018    77805
# 2019    77130
# Name: Poisonings, dtype: int64

# %%
#14 Country that died of poison the most
poison_country = df2[df2["Poisonings"] > 0].groupby('Country/Territory')["Poisonings"].sum().sort_values(ascending= False)
poison_country
# Out:
# Country/Territory
# China                               770140
# Russia                              298954
# India                               170119
# Nigeria                             107604
# Ethiopia                            101065
#                                      ...
# Saint Lucia                              9
# Antigua and Barbuda                      8
# Bermuda                                  5
# Monaco                                   5
# Saint Vincent and the Grenadines         3
# Name: Poisonings, Length: 191, dtype: int64

# %%
#15 Country with its's corresponding years with the most poisonings
poison = df2[(df2["Poisonings"]) > 0 & (df2["Year"] != 0)].groupby(['Country/Territory', "Year"])["Poisonings"].sum().sort_values(ascending= False)
poison
# Out:
# Country/Territory      Year
# China                  2011    30883
#                        2010    30838
#                        2012    30494
#                        2013    30263
#                        2009    30105
#                                ...
# Samoa                  1996        1
#                        1997        1
#                        1998        1
#                        1999        1
# Sao Tome and Principe  2014        1
# Name: Poisonings, Length: 5536, dtype: int64

# %%
#16 Is death of Lower Respiratory Infection common in australia
australia = df2[df2["Country/Territory"] == 'Australia'].groupby('Year')['Lower Respiratory Infections'].sum()
australia
# Out:
# Year
# 1990    1823
# 1991    1826
# 1992    1895
# 1993    1924
# 1994    2043
# 1995    2136
# 1996    2323
# 1997    2638
# 1998    2547
# 1999    2620
# 2000    2838
# 2001    2940
# 2002    3097
# 2003    3181
# 2004    3113
# 2005    2998
# 2006    2938
# 2007    2910
# 2008    2828
# 2009    2803
# 2010    2911
# 2011    3055
# 2012    3192
# 2013    3306
# 2014    3530
# 2015    3763
# 2016    3925
# 2017    4011
# 2018    4158
# 2019    4269
# Name: Lower Respiratory Infections, dtype: int64

# %%
#17 Do russians die a lot from conflicts
russian_conflict = df2[df2["Country/Territory"] == 'Russia'].groupby('Year')['Conflict and Terrorism'].sum()
russian_conflict
# Out:
# Year
# 1990     192
# 1991     271
# 1992      36
# 1993     147
# 1994     277
# 1995    2055
# 1996    2901
# 1997      75
# 1998      57
# 1999    7145
# 2000    6617
# 2001    4513
# 2002    2644
# 2003    1185
# 2004    2175
# 2005    1043
# 2006     398
# 2007     299
# 2008     574
# 2009     883
# 2010    1139
# 2011     564
# 2012    1347
# 2013    1339
# 2014     266
# 2015     415
# 2016     225
# 2017     187
# 2018     136
# 2019      20
# Name: Conflict and Terrorism, dtype: int64

# %%
#18 What Country is the safest to live in (per conflicts death)
safe_country = df2[df2['Conflict and Terrorism'] > 0].groupby('Country/Territory')['Conflict and Terrorism'].sum().sort_values(ascending= True)
safe_country
# Out:
# Country/Territory
# Luxembourg                   1
# Suriname                     1
# Antigua and Barbuda          1
# Dominica                     1
# United Arab Emirates         2
#                          ...
# Burundi                 163935
# Afghanistan             280520
# Iraq                    336980
# Syria                   365293
# Rwanda                  528779
# Name: Conflict and Terrorism, Length: 177, dtype: int64

# %%
#19 Road Injuries and Malaria which has more deaths in U.S
us_deaths = df2[df2['Country/Territory'] == 'United States'].groupby('Year')[['Road Injuries', 'Malaria']].sum()
us_deaths
# Out:
#       Road Injuries  Malaria
# Year
# 1990          48970        0
# 1991          47833        0
# 1992          46690        0
# 1993          47119        0
# 1994          47262        0
# 1995          47551        0
# 1996          47416        0
# 1997          47374        0
# 1998          47341        0
# 1999          47717        0
# 2000          48207        0
# 2001          48737        0
# 2002          49318        0
# 2003          49243        0
# 2004          48526        0
# 2005          48654        0
# 2006          48092        0
# 2007          46498        0
# 2008          44535        0
# 2009          42561        0
# 2010          40874        0
# 2011          40383        0
# 2012          39985        0
# 2013          39785        0
# 2014          40155        0
# 2015          41198        0
# 2016          42360        0
# 2017          42206        0
# 2018          41792        0
# 2019          41362        0

# %%
#20 Road Injuries and Malaria which has more deaths in Nigeria
nga_deathss = df2[df2['Country/Territory'] == 'Nigeria'].groupby('Year')[['Road Injuries', 'Malaria']].sum()
nga_deathss
# Out:
#       Road Injuries  Malaria
# Year
# 1990          11832   148931
# 1991          12185   157502
# 1992          12663   165722
# 1993          13082   173695
# 1994          13421   180588
# 1995          13667   186263
# 1996          13879   191437
# 1997          14199   197467
# 1998          14574   202843
# 1999          14916   207571
# 2000          15229   212123
# 2001          15536   221139
# 2002          16012   226408
# 2003          16341   235380
# 2004          16690   236937
# 2005          16867   243827
# 2006          17447   257505
# 2007          17720   267368
# 2008          17507   280604
# 2009          17658   276715
# 2010          17801   266638
# 2011          17997   254072
# 2012          18358   239886
# 2013          18610   227310
# 2014          18723   218689
# 2015          19053   204672
# 2016          19370   186482
# 2017          19319   176183
# 2018          18531   187000
# 2019          18508   191106
